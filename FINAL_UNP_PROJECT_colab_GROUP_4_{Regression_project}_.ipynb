# %% [markdown]
# #***Data***
# The term 'data' in a project broadly refers to all the information and documents collected, analyzed, and utilized to plan, execute, monitor, and control the project. This data plays a pivotal role in making informed decisions, managing risks, and ensuring that the project objectives are met. By leveraging this information, project managers can take well-informed decisions and steer the project towards a successful conclusion.

# %% [markdown]
# #Importing Python Libraries
# To proceed with data analysis and visualization in Python, we need to import some important modules such as pandas, numpy, seaborn, and matplotlib. Pandas is used for data analysis, numpy for calculating n-dimensional arrays, and seaborn and matplotlib for data visualization.

# %%
 #importing pandas
 import pandas as pd
 #importing numpy
 import numpy as np
 #importing seaborn
 import seaborn as sns
 #importing matplotlib
 import matplotlib.pyplot as plt
 #importing xgboost
 from xgboost import XGBClassifier
 #importing models
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #Importing Machine Learning Libraries
# To perform machine learning tasks such as creating regression lines, splitting the lines, and predicting values, we need to import some important modules from the sci-kit-learn library (sklearn). These modules include train_test_split, StandardScaler, LinearRegression, mean_squared_error, Ridge, Lasso, and RandomForestRegressor.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# #Reading the Data Set
# Usually, datasets come in the form of CSV files, but in this case, the file is in Excel format. To read this Excel file in Python, we will use the Pandas library
# (df=dataframe).

# %%
#reading the data
df = pd.read_csv('/content/drive/MyDrive/project1.csv')
df
# Out:
#             date   quarter  department        day  team  \
# 0     01-01-2015  Quarter1      sweing   Thursday     8
# 1     01-01-2015  Quarter1  finishing    Thursday     1
# 2     01-01-2015  Quarter1      sweing   Thursday    11
# 3     01-01-2015  Quarter1      sweing   Thursday    12
# 4     01-01-2015  Quarter1      sweing   Thursday     6
# ...          ...       ...         ...        ...   ...
# 1192  03-11-2015  Quarter2   finishing  Wednesday    10
# 1193  03-11-2015  Quarter2   finishing  Wednesday     8
# 1194  03-11-2015  Quarter2   finishing  Wednesday     7
# 1195  03-11-2015  Quarter2   finishing  Wednesday     9
# 1196  03-11-2015  Quarter2   finishing  Wednesday     6
#
#       targeted_productivity    smv     wip  over_time  incentive  idle_time  \
# 0                      0.80  26.16  1108.0       7080         98        0.0
# 1                      0.75   3.94     NaN        960          0        0.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Data Cleaning
# Data cleaning is a meticulous and time-consuming process that requires a keen eye for detail, an in-depth understanding of the domain, and the use of appropriate tools and techniques. It is an indispensable step in any data-related project, as accurate and reliable data is crucial to making informed decisions and achieving precise results in data analysis, machine learning, and other data-driven tasks. Without proper data cleaning, the output of a project can be severely impacted by inaccuracies and inconsistencies in the data. Therefore, it is imperative to invest time and effort in data cleaning to ensure the quality and integrity of the data.
#
# #Dropping Duplicate Values of the Data Set
# It is common for a dataset to contain duplicate rows. These duplicates only make the dataset larger and have no value for data analysis. Therefore, it is necessary to identify and drop any duplicate rows in the dataset.

# %%
# Dropping the duplicates values, if any
df = df.drop_duplicates()
df
# Out:
#             date   quarter  department        day  team  \
# 0     01-01-2015  Quarter1      sweing   Thursday     8
# 1     01-01-2015  Quarter1  finishing    Thursday     1
# 2     01-01-2015  Quarter1      sweing   Thursday    11
# 3     01-01-2015  Quarter1      sweing   Thursday    12
# 4     01-01-2015  Quarter1      sweing   Thursday     6
# ...          ...       ...         ...        ...   ...
# 1192  03-11-2015  Quarter2   finishing  Wednesday    10
# 1193  03-11-2015  Quarter2   finishing  Wednesday     8
# 1194  03-11-2015  Quarter2   finishing  Wednesday     7
# 1195  03-11-2015  Quarter2   finishing  Wednesday     9
# 1196  03-11-2015  Quarter2   finishing  Wednesday     6
#
#       targeted_productivity    smv     wip  over_time  incentive  idle_time  \
# 0                      0.80  26.16  1108.0       7080         98        0.0
# 1                      0.75   3.94     NaN        960          0        0.0
# ...

# %% [markdown]
# #***Describing the Data Set***
# We can utilize the describe() function to provide an overview of the Data Set and calculate various statistics for each data point in the feature.

# %%
#describing the data
df.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1197.000000            1197.000000  1197.000000    691.000000
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1837.455001
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    774.500000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1252.500000
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men  \
# count   1197.000000  1197.000000  1197.000000  1197.000000
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# ...

# %%
cols = df.columns

# %%
print(cols)
# Out:
# Index(['date', 'quarter', 'department', 'day', 'team', 'targeted_productivity',
#        'smv', 'wip', 'over_time', 'incentive', 'idle_time', 'idle_men',
#        'no_of_style_change', 'no_of_workers', 'actual_productivity'],
#       dtype='object')

# %%
for c in cols:
  print("unique values of ",c ,"\n")
print(df[c].unique())
# Out:
# unique values of  date
#
# unique values of  quarter
#
# unique values of  department
#
# unique values of  day
#
# unique values of  team
#
# unique values of  targeted_productivity
#
# unique values of  smv
#
# unique values of  wip
#
# unique values of  over_time
#
# unique values of  incentive
#
# unique values of  idle_time
#
# unique values of  idle_men
#
# unique values of  no_of_style_change
#
# unique values of  no_of_workers
#
# unique values of  actual_productivity
#
# [0.94072542 0.8865     0.80057049 0.80038194 0.800125   0.75516667
#  0.75368348 0.75309753 0.75042783 0.72112696 0.71220525 0.7070459
#  0.70591667 0.67666667 0.59305556 0.54072917 0.52118    0.43632639
#  0.98802469 0.98788044 0.95627083 0.94527778 0.90291667 0.80072531
#  0.80032294 0.80031864 0.80023729 0.80014865 0.78729969 0.78244792
#  0.75024303 0.7018125  0.70013404 0.69996522 0.62833333 0.6253125
#  0.99138889 0.93164583 0.91522917 0.87971448 0.86167901 0.85056949
# ...

# %%
df.sort_values(by=cols[-1], ascending=True).head()
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 147  01-08-2015  Quarter2      sweing   Thursday     5                    0.7
# 317   1/18/2015  Quarter3  finishing      Sunday    10                    0.7
# 765   2/14/2015  Quarter2   finishing   Saturday     9                    0.8
# 215  01-12-2015  Quarter2  finishing      Monday    10                    0.8
# 258   1/14/2015  Quarter2  finishing   Wednesday     2                    0.8
#
#        smv    wip  over_time  incentive  idle_time  idle_men  \
# 147  42.41  724.0      10260          0        0.0         0
# 317   3.94    NaN       1440          0        0.0         0
# 765   3.94    NaN        960          0        0.0         0
# 215   3.94    NaN       1440          0        0.0         0
# 258   3.94    NaN       1260          0        0.0         0
#
#      no_of_style_change  no_of_workers  actual_productivity
# 147                   0           57.0             0.233705
# ...

# %%
print('Unique Vaues in Department before cleaning:')
print(df.department.unique())
df['department'] = df.department.str.strip()

print('Unique Vaues in Department afer cleaning:')
print(df.department.unique())
# Out:
# Unique Vaues in Department before cleaning:
# ['sweing' 'finishing ' 'finishing']
# Unique Vaues in Department afer cleaning:
# ['sweing' 'finishing']

# %%
print(df.department.unique())
# Out:
# ['sweing' 'finishing']

# %% [markdown]
# #Type of Data Set we have
# To extract information from the dataset, we utilize a specific function after analyzing the data. During this analysis, we also take note of the null value count for each feature and determine the data type of the features present in the dataset.

# %% [markdown]
# ###Top down approach
# 1.  first we look at the dataset from the birds eye view

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
# ...

# %% [markdown]
# #Handling Null values
# To improve accuracy, we address any null values found in the dataset using the isnull() function.

# %%
df.isnull().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
#removing the NaN values, replacing by mean
df["wip"] = df["wip"].fillna('1039.000000')
df
# Out:
#             date   quarter  department        day  team  \
# 0     01-01-2015  Quarter1      sweing   Thursday     8
# 1     01-01-2015  Quarter1  finishing    Thursday     1
# 2     01-01-2015  Quarter1      sweing   Thursday    11
# 3     01-01-2015  Quarter1      sweing   Thursday    12
# 4     01-01-2015  Quarter1      sweing   Thursday     6
# ...          ...       ...         ...        ...   ...
# 1192  03-11-2015  Quarter2   finishing  Wednesday    10
# 1193  03-11-2015  Quarter2   finishing  Wednesday     8
# 1194  03-11-2015  Quarter2   finishing  Wednesday     7
# 1195  03-11-2015  Quarter2   finishing  Wednesday     9
# 1196  03-11-2015  Quarter2   finishing  Wednesday     6
#
#       targeted_productivity    smv          wip  over_time  incentive  \
# 0                      0.80  26.16       1108.0       7080         98
# 1                      0.75   3.94  1039.000000        960          0
# 2                      0.80  11.41        968.0       3660         50
# ...

# %% [markdown]
# # **EDA(Exploratory Data Analysis) on the data**

# %% [markdown]
# # The unique values in the Data Set
# In pandas, there exists a method for discovering every distinct value within a dataset. This can be accomplished by utilizing the nunique() function.

# %%
df.nunique()
# Out:
# date                      59
# quarter                    5
# department                 3
# day                        6
# team                      12
# targeted_productivity      9
# smv                       70
# wip                      549
# over_time                143
# incentive                 48
# idle_time                 12
# idle_men                  10
# no_of_style_change         3
# no_of_workers             61
# actual_productivity      879
# dtype: int64

# %% [markdown]
# #Correlation Plot
# The correlation plot is a visual representation of the correlation coefficient between variables, which is displayed in the form of a matrix-like table. To visualize the correlation between variables, we use the seaborn library to plot the correlation plot. This plot displays a one-to-one relationship between variables, with each variable showing its relationship with another variable. Upon observing the heatmap, we can see that cement has a strong correlation with water.

# %%
df.corr()
# Out:
# <ipython-input-38-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                            team  targeted_productivity       smv  over_time  \
# team                   1.000000               0.030274 -0.110011  -0.096737
# targeted_productivity  0.030274               1.000000 -0.069489  -0.088557
# smv                   -0.110011              -0.069489  1.000000   0.674887
# over_time             -0.096737              -0.088557  0.674887   1.000000
# incentive             -0.007674               0.032768  0.032629  -0.004793
# idle_time              0.003796              -0.056181  0.056863   0.031038
# idle_men               0.026974              -0.053818  0.105901  -0.017913
# no_of_style_change    -0.011194              -0.209294  0.315388   0.059790
# ...

# %%
#Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap using Seaborn
plt.figure(figsize=(12, 10))
sns.set(font_scale=1.0)  # Adjust the font size for better readability
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, square=True)

# Customize the plot
plt.title("Correlation Heatmap")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-f3bc6a43ac6b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# # **Pie Charts**

# %%
categorical = [ 'quarter', 'department', 'day', 'team', 'no_of_style_change','actual_productivity']

# %%
for i in range(len(categorical)):
    print(categorical[i])
    df[categorical[i]].value_counts().plot(kind='pie', autopct="%.3f")
    plt.show()
# Out:
# quarter
# department
# day
# team
# no_of_style_change
# actual_productivity

# %% [markdown]
# #***Appyling Regression***
# Regression analysis can be a useful tool in a project, depending on the goals and the type of data involved. It allows for better comprehension, prediction, and optimization of different aspects of the project. This method is extensively applied in diverse fields such as finance, marketing, healthcare, and engineering.

# %% [markdown]
# ###***Dividing Dependent And Independent Variables***
# Before starting model building, it is important to divide the dataset into two parts: independent variables and dependent variable. The independent variables contain a list of those variables on which the actual_productivity is dependent, while the dependent variable is the variable that is dependent on the values of other variables.

# %%
# Independent variable
x = df.drop(['actual_productivity','date','quarter','department','day'], axis =1)
# dependent variable
y = df['actual_productivity']

# %% [markdown]
# ##***Splitting the data***
# To split the training and testing parts, we can use the scikit-learn module train_test_split.

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# #Feature Scaling
# We do the scaling of the data for balancing the data points

# %%
stand= StandardScaler()
Fit = stand.fit(xtrain)
xtrain_scl = Fit.transform(xtrain)
xtest_scl = Fit.transform(xtest)

# %% [markdown]
# # **Data Modeling and selection**

# %% [markdown]
# #***Applying model***
# Using a model in a project means putting the model's insights or predictions into practical use to achieve the project's objectives. This may include making real-time decisions, automating specific processes, improving efficiency, and ultimately delivering value to the organization or end-users. It is crucial to continually assess and update the applied model to ensure its accuracy and relevance in changing circumstances.

# %%
lr=LinearRegression()
fit=lr.fit(xtrain_scl,ytrain)
score = lr.score(xtest_scl,ytest)
print('Predcted score is : {}'.format(score))
print('..................................')
y_predict = lr.predict(xtest_scl)
print('Mean_Sqrd_Error is ==',mean_squared_error(ytest,y_predict))
rms = np.sqrt(mean_squared_error(ytest,y_predict))
print('Root Mean Squared Error is == {}'.format(rms))
# Out:
# Predcted score is : 0.21941100545039216
# ..................................
# Mean_Sqrd_Error is == 0.023330290868656647
# Root Mean Squared Error is == 0.1527425640371951

# %% [markdown]
# #Now, we plot a scatter plot and fit the line for checking the prediction values

# %%
# The plot of predicition value
plt.figure(figsize=[17,8])
plt.scatter(y_predict,ytest)
plt.plot([ytest.min(), ytest.max()], [ytest.min(), ytest.max()], color='red')
plt.xlabel('Predicted')
plt.ylabel('Orignal')
plt.show()

# %% [markdown]
# #Lasso and Ridge Regression

# %%
rd= Ridge(alpha=0.4)
ls= Lasso(alpha=0.3)
fit_rd=rd.fit(xtrain_scl,ytrain)
fit_ls = ls.fit(xtrain_scl,ytrain)
print('Score of Ridge Regression is:-',rd.score(xtest_scl,ytest))
print('.......................................................')
print('Score of Lasso Regression is:-',ls.score(xtest_scl,ytest))
print('Mean_Sqrd_Error of Ridge Regression is==',mean_squared_error(ytest,rd.predict(xtest_scl)))
print('mean_sqrd_error of Lasso Regression is==',mean_squared_error(ytest,ls.predict(xtest_scl)))
print('root_mean_squared error of Ridge Regression is==',np.sqrt(mean_squared_error(ytest,rd.predict(xtest_scl))))
print('root_mean_squared error of Lasso Regression is==',np.sqrt(mean_squared_error(ytest,lr.predict(xtest_scl))))
# Out:
# Score of Ridge Regression is:- 0.21951625166901234
# .......................................................
# Score of Lasso Regression is:- -0.0002750925435928142
# Mean_Sqrd_Error of Ridge Regression is== 0.02332714526333761
# mean_sqrd_error of Lasso Regression is== 0.02989628219288374
# root_mean_squared error of Ridge Regression is== 0.1527322666083942
# root_mean_squared error of Lasso Regression is== 0.1527425640371951

# %% [markdown]
# This regression algorithm produces slightly different prediction scores compared to linear regression.
#
# Next, we will generate a scatter plot displaying the predicted data and overlay a line on top of it.
#
# #The Plot of Ridge Regression

# %%
# The plot of rigid regression
plt.figure(figsize=[17,8])
plt.scatter(y_predict,ytest)
plt.plot([ytest.min(), ytest.max()], [ytest.min(), ytest.max()], color='red')
plt.xlabel('Predicted')
plt.ylabel('Orignal')
plt.show()

# %% [markdown]
# # The plot of rigid regression

# %%
#The plot of lasso regression
plt.figure(figsize=[17,8])
plt.scatter(y_predict,ytest)
plt.plot([ytest.min(), ytest.max()], [ytest.min(), ytest.max()], color='red')
plt.xlabel('Predicted')
plt.ylabel('Orignal')
plt.show()

# %% [markdown]
# When we compare these two plots, we can see that the prediction scores for both algorithms are very similar.
#
# #Random Forest Regressor

# %%
rnd= RandomForestRegressor(ccp_alpha=0.0)
fit_rnd= rnd.fit(xtrain_scl,ytrain)
print('Score is:-',rnd.score(xtest_scl,ytest))
print('........................................')
print('Mean_Sqrd_Error is==',mean_squared_error(ytest,rnd.predict(xtest_scl)))
print('Root_Mean_Squared Error of is==',np.sqrt(mean_squared_error(ytest,rnd.predict(xtest_scl))))
# Out:
# Score is:- 0.42999900132414526
# ........................................
# Mean_Sqrd_Error is== 0.017036224168399203
# Root_Mean_Squared Error of is== 0.130522887527051

# %% [markdown]
# #***Predicted Values vs Original Values***
#
# We can now compare the predicted values of the dependent variable "Concrete Compressive Strength" with the original values of the same variable to determine the level of compression.

# %%
x_predict = list(rnd.predict(xtest))
predicted_df = {'predicted_values': x_predict, 'original_values': ytest}
#creating new dataframe
pd.DataFrame(predicted_df).head(15)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
#       predicted_values  original_values
# 921           0.535296         0.268214
# 321           0.852421         0.800359
# 101           0.620090         0.681061
# 920           0.529287         0.325000
# 58            0.620090         0.667604
# 790           0.516300         0.800980
# 948           0.529786         0.768847
# 969           0.529786         0.768847
# 410           0.852421         0.650417
# 1079          0.852421         0.750396
# 572           0.852421         0.700398
# 44            0.529287         0.861679
# 49            0.853176         0.800319
# 844           0.529287         0.816406
# 240           0.852421         0.900145

# %%
models = [LinearRegression()]

# %% [markdown]
# ##Saving the Model
# Now, we save our machine learning model using pickle.

# %%
import pickle
file = 'concrete_strength'
save = pickle.dump(rnd,open(file,'wb'))
